# %%
import pandas as pd
import os

# 切换到项目根目录或目标数据目录
os.chdir("/Users/dallylovely/Desktop/CCGG/Projects/recommendation_system")

# %%
import pandas as pd
from src.data.load_behavior_log import find_window_bounds
from src.recall.youtube_dnn.dataset_youtube_dnn import YoutubeDNNDataset

# %%
# 配置路径
USER_PROFILE_CSV = "data/processed/user_profile_feature.csv"
ITEM_METADATA_CSV = "data/raw/item_metadata.csv"
BEHAVIOR_CSV = "data/raw/user_behavior_log_info.csv"

# 时间窗口
_, cutoff_date, upper_date = find_window_bounds(
    BEHAVIOR_CSV, chunksize=100_000, days_window=30
)

# 初始化 Dataset
dataset = YoutubeDNNDataset(
    user_profile_csv=USER_PROFILE_CSV,
    item_csv=ITEM_METADATA_CSV,
    behavior_csv=BEHAVIOR_CSV,
    cutoff_date=cutoff_date,
    upper_date=upper_date,
    chunksize=100_000,
    num_negatives=4,
    max_text_feat_dim=300,
    filter_item_ids=None  # ✅ 默认取 metadata ∩ behavior
)

print("✅ Dataset 初始化完成")
# Out:
# 2025-08-26 14:50:00,415 INFO:Max behavior date found: 2024-11-12 00:00:00, window from 2024-10-14 00:00:00 to 2024-11-13 00:00:00
# 2025-08-26 14:50:01,892 INFO:Loaded user profile from data/processed/user_profile_feature.csv, shape = (424170, 34)
# 2025-08-26 14:50:02,465 INFO:Successfully loaded file: data/raw/item_metadata.csv
# 2025-08-26 14:50:02,467 INFO:Dropped 0 rows with invalid item_id
# 2025-08-26 14:50:03,534 INFO:Filtered chunk by valid actions: 46421 → 46421
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:04,058 INFO:Filtered chunk by valid actions: 47080 → 47080
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:04,496 INFO:Filtered chunk by valid actions: 46894 → 46894
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:05,002 INFO:Filtered chunk by valid actions: 46234 → 46234
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:05,436 INFO:Filtered chunk by valid actions: 46398 → 46398
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:05,893 INFO:Filtered chunk by valid actions: 46068 → 46068
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:06,366 INFO:Filtered chunk by valid actions: 45999 → 45999
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:06,929 INFO:Filtered chunk by valid actions: 46600 → 46600
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:07,809 INFO:Filtered chunk by valid actions: 46713 → 46713
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:08,342 INFO:Filtered chunk by valid actions: 47940 → 47940
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:08,836 INFO:Filtered chunk by valid actions: 47776 → 47776
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:09,335 INFO:Filtered chunk by valid actions: 48352 → 48352
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:09,783 INFO:Filtered chunk by valid actions: 49518 → 49518
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:10,238 INFO:Filtered chunk by valid actions: 49426 → 49426
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:10,661 INFO:Filtered chunk by valid actions: 52845 → 52845
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:11,175 INFO:Filtered chunk by valid actions: 58799 → 58799
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:11,684 INFO:Filtered chunk by valid actions: 47295 → 47295
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:12,136 INFO:Filtered chunk by valid actions: 46202 → 46202
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:12,573 INFO:Filtered chunk by valid actions: 46866 → 46866
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:12,998 INFO:Filtered chunk by valid actions: 46493 → 46493
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:13,433 INFO:Filtered chunk by valid actions: 45676 → 45676
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:13,859 INFO:Filtered chunk by valid actions: 45883 → 45883
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:14,777 INFO:Filtered chunk by valid actions: 46779 → 46779
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:15,261 INFO:Filtered chunk by valid actions: 46367 → 46367
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:15,698 INFO:Filtered chunk by valid actions: 47179 → 47179
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:16,324 INFO:Filtered chunk by valid actions: 46996 → 46996
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:16,925 INFO:Filtered chunk by valid actions: 48493 → 48493
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:17,371 INFO:Filtered chunk by valid actions: 48775 → 48775
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:17,790 INFO:Filtered chunk by valid actions: 49455 → 49455
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:18,342 INFO:Filtered chunk by valid actions: 52503 → 52503
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:18,812 INFO:Filtered chunk by valid actions: 51482 → 51482
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:19,316 INFO:Filtered chunk by valid actions: 57435 → 57435
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:19,754 INFO:Filtered chunk by valid actions: 47758 → 47758
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:20,198 INFO:Filtered chunk by valid actions: 47651 → 47651
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:20,704 INFO:Filtered chunk by valid actions: 46107 → 46107
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:21,227 INFO:Filtered chunk by valid actions: 46697 → 46697
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:22,056 INFO:Filtered chunk by valid actions: 47030 → 47030
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:22,591 INFO:Filtered chunk by valid actions: 46021 → 46021
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:23,096 INFO:Filtered chunk by valid actions: 47073 → 47073
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:23,547 INFO:Filtered chunk by valid actions: 47478 → 47478
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:24,002 INFO:Filtered chunk by valid actions: 47355 → 47355
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:24,505 INFO:Filtered chunk by valid actions: 48538 → 48538
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:24,955 INFO:Filtered chunk by valid actions: 48038 → 48038
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:25,440 INFO:Filtered chunk by valid actions: 49239 → 49239
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:25,928 INFO:Filtered chunk by valid actions: 48721 → 48721
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:26,411 INFO:Filtered chunk by valid actions: 51182 → 51182
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:27,007 INFO:Filtered chunk by valid actions: 55882 → 55882
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:27,536 INFO:Filtered chunk by valid actions: 52511 → 52511
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:28,061 INFO:Filtered chunk by valid actions: 47322 → 47322
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:49,771 INFO:Filtered chunk by valid actions: 47885 → 47885
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:50,236 INFO:Filtered chunk by valid actions: 46758 → 46758
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:50,656 INFO:Filtered chunk by valid actions: 46513 → 46513
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:51,101 INFO:Filtered chunk by valid actions: 46297 → 46297
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:51,644 INFO:Filtered chunk by valid actions: 46352 → 46352
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:52,103 INFO:Filtered chunk by valid actions: 45382 → 45382
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:52,624 INFO:Filtered chunk by valid actions: 47453 → 47453
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:53,099 INFO:Filtered chunk by valid actions: 46042 → 46042
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:53,542 INFO:Filtered chunk by valid actions: 47631 → 47631
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:54,013 INFO:Filtered chunk by valid actions: 46921 → 46921
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:54,452 INFO:Filtered chunk by valid actions: 48514 → 48514
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:54,888 INFO:Filtered chunk by valid actions: 49524 → 49524
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:55,429 INFO:Filtered chunk by valid actions: 49610 → 49610
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:55,877 INFO:Filtered chunk by valid actions: 50644 → 50644
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:56,365 INFO:Filtered chunk by valid actions: 52675 → 52675
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)
# 2025-08-26 14:50:56,766 INFO:Filtered chunk by valid actions: 52721 → 52721
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["user_id"] = chunk["user_id"].astype(str)
# /Users/dallylovely/Desktop/CCGG/Projects/recommendation_system/src/recall/youtube_dnn/dataset_youtube_dnn.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk["item_id"] = chunk["item_id"].astype(str)

# %%
# ----------------------------
# 打印数据信息
# ----------------------------

print("✅ Dataset 初始化完成")
print(f"样本总数 (正样本 + 负样本): {len(dataset)}")

# 用户数、物品数
n_users, n_items = dataset.get_num_users_items()
print(f"用户总数: {n_users}")
print(f"物品总数: {n_items}")

# 用户特征 vocab
print("用户类别特征 vocab sizes:", dataset.get_user_categorical_vocab_sizes())

# 数值特征均值和方差
print("用户数值特征 norm:", dataset.get_user_numeric_norm())

# item 文本特征维度
print(f"Item 文本 TF-IDF 向量维度: {dataset.get_item_text_dim()}")
# Out:
# ✅ Dataset 初始化完成
# 样本总数 (正样本 + 负样本): 561910
# 用户总数: 424170
# 物品总数: 419
# 用户类别特征 vocab sizes: {'gender': 3, 'age_range': 9, 'city': 15, 'cluster_id': 4}
# 用户数值特征 norm: {'mean': array([ 1.4401301, 12.538259 ,  3.1723707], dtype=float32), 'std': array([ 2.690012 , 17.5567   ,  3.3856869], dtype=float32), 'cols': ['recency', 'frequency', 'actions_per_active_day_30d']}
# Item 文本 TF-IDF 向量维度: 300

# %%
# ----------------------------
# 打印用户数对比
# ----------------------------
profile_users = dataset.users["user_id"].nunique()
print(f"用户画像文件 (profile.csv) 用户数: {profile_users}")

# 从原始行为日志中统计用户数（不过滤）
raw_behavior_users = pd.read_csv(
    BEHAVIOR_CSV,
    usecols=["user_id"],
    dtype=str,
    nrows=200_000  # ⚠️ 可以先采样部分加速
)["user_id"].nunique()
print(f"行为日志 (behavior.csv) 用户数 (采样): {raw_behavior_users}")

# 真实参与训练的用户数（三方交集后）
active_users = dataset.interactions["user_id"].nunique()
print(f"三方交集后 (有效交互用户) 用户数: {active_users}")

# ----------------------------
# 打印物品数对比
# ----------------------------
metadata_items = dataset.items["item_id"].nunique()
print(f"物品元数据 (metadata.csv) 物品数: {metadata_items}")

active_items = dataset.interactions["item_id"].nunique()
print(f"三方交集后 (有效交互物品) 物品数: {active_items}")

# ----------------------------
# 打印一个样本
# ----------------------------
print("\n👀 随机查看一个训练样本:")
print(dataset[0])
# Out:
# 用户画像文件 (profile.csv) 用户数: 424170
# 行为日志 (behavior.csv) 用户数 (采样): 6601
# 三方交集后 (有效交互用户) 用户数: 39983
# 物品元数据 (metadata.csv) 物品数: 419
# 三方交集后 (有效交互物品) 物品数: 335
#
# 👀 随机查看一个训练样本:
# (tensor(141468), tensor(25), tensor(1.), tensor(1), tensor(6), tensor(14), tensor(1), tensor([-0.1636, -0.3154, -0.4201]), tensor([0.0197, 0.0000, 0.0000, 0.0098, 0.0000, 0.0196, 0.0275, 0.0000, 0.0199,
#         0.0179, 0.0000, 0.0000, 0.0000, 0.0000, 0.0758, 0.0294, 0.0474, 0.0427,
#         0.0580, 0.2065, 0.0000, 0.0216, 0.0000, 0.0098, 0.0774, 0.0000, 0.0208,
#         0.0581, 0.0432, 0.0207, 0.0196, 0.0414, 0.0593, 0.0228, 0.0000, 0.0684,
#         0.0000, 0.0223, 0.0000, 0.0000, 0.0000, 0.0000, 0.0948, 0.0553, 0.0000,
#         0.0145, 0.0230, 0.0000, 0.1084, 0.0000, 0.0000, 0.0000, 0.0000, 0.0904,
#         0.0000, 0.0254, 0.0098, 0.0098, 0.0149, 0.0705, 0.0248, 0.0000, 0.0775,
#         0.0220, 0.0242, 0.0000, 0.0000, 0.0192, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0233, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0474, 0.0000,
#         0.0000, 0.0524, 0.0261, 0.0196, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0182, 0.0000, 0.1177, 0.0000, 0.0000, 0.0000, 0.0216, 0.0225, 0.0365,
#         0.0236, 0.0238, 0.0000, 0.0542, 0.0000, 0.0136, 0.0319, 0.0558, 0.0134,
#         0.0000, 0.0212, 0.0000, 0.0222, 0.0000, 0.0179, 0.0219, 0.0175, 0.0000,
#         0.1421, 0.0487, 0.0000, 0.3335, 0.0365, 0.0265, 0.0000, 0.2115, 0.0906,
#         0.0140, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0257, 0.0098, 0.0000, 0.0249, 0.0000, 0.0230, 0.0512, 0.0000,
#         0.0000, 0.0195, 0.0397, 0.0000, 0.0278, 0.0000, 0.0000, 0.0556, 0.0000,
#         0.1073, 0.0000, 0.0000, 0.0514, 0.0000, 0.0238, 0.0000, 0.0243, 0.0217,
#         0.0434, 0.0000, 0.0000, 0.0549, 0.0000, 0.0256, 0.0545, 0.0236, 0.1177,
#         0.0230, 0.0000, 0.0697, 0.0594, 0.0207, 0.0743, 0.0000, 0.0392, 0.0304,
#         0.0140, 0.0000, 0.0000, 0.0284, 0.0281, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0275, 0.0000, 0.0000, 0.0465, 0.0244, 0.0197, 0.0098, 0.0000,
#         0.0262, 0.0098, 0.0196, 0.0248, 0.0098, 0.0000, 0.1044, 0.0000, 0.0788,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0250, 0.0180, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0098, 0.0000, 0.0000, 0.0000, 0.0162, 0.0251, 0.0000, 0.0000,
#         0.0000, 0.0474, 0.0000, 0.0219, 0.0000, 0.0519, 0.0192, 0.0000, 0.0000,
#         0.0000, 0.0904, 0.0454, 0.1181, 0.6377, 0.0098, 0.0278, 0.0000, 0.0000,
#         0.0567, 0.0000, 0.0871, 0.0476, 0.0000, 0.0394, 0.0000, 0.0000, 0.0162,
#         0.1766, 0.0000, 0.0241, 0.0000, 0.0000, 0.0000, 0.0000, 0.1466, 0.0000,
#         0.0000, 0.0000, 0.0230, 0.0281, 0.0887, 0.0000, 0.0232, 0.0262, 0.0241,
#         0.0206, 0.0000, 0.0746, 0.0000, 0.0208, 0.0497, 0.0000, 0.0227, 0.0000,
#         0.0401, 0.0000, 0.0000, 0.0469, 0.0375, 0.0372, 0.0187, 0.0443, 0.0000,
#         0.0604, 0.0634, 0.0000, 0.0181, 0.0501, 0.0868, 0.0279, 0.0000, 0.0000,
#         0.0000, 0.0258, 0.0000]), tensor(1.))

# %%
# Step 2: 加载行为数据
behavior_df = pd.read_csv("data/raw/user_behavior_log_info.csv")

# %%
# Step 3: 构建 dt 时间列
mmd_str = behavior_df["time_stamp"].astype(str).str.zfill(4)
month = mmd_str.str[:2]
day = mmd_str.str[2:]
behavior_df["dt"] = pd.to_datetime(
    behavior_df["year"].astype(str) + "-" + month + "-" + day,
    errors='coerce'
) + pd.to_timedelta(behavior_df["timestamp"], unit="s")

# %%
# Step 4: 只取最近 7 天点击
max_dt = behavior_df["dt"].max()
min_dt = max_dt - pd.Timedelta(days=7)
click_df = behavior_df[
    (behavior_df["dt"] >= min_dt) &
    (behavior_df["dt"] <= max_dt) &
    (behavior_df["action_type"].str.lower() == "click")
]

# %%
# Step 5: 判断点击的 item 是否出现在 item_metadata 中
total_gt = len(click_df)
in_vocab = click_df["item_id"].astype(str).isin(valid_items).sum()
ratio = round(in_vocab / total_gt, 4) if total_gt > 0 else 0

print(f"✅ Ground Truth 总点击数: {total_gt}")
print(f"📦 其中出现在 item_metadata 的 item 数: {in_vocab}")
print(f"📉 命中比例: {ratio * 100:.2f}%")
# Out:
# ✅ Ground Truth 总点击数: 3132633
# 📦 其中出现在 item_metadata 的 item 数: 89019
# 📉 命中比例: 2.84%

# %%
recall_df = pd.read_csv("output/youtube_dnn/youtube_dnn_faiss_recall.csv")
behavior_df = pd.read_csv("data/raw/user_behavior_log_info.csv")
item_df = pd.read_csv("data/raw/item_metadata.csv")

# %%
from src.data.load_behavior_log import build_datetime

# %%
# Ground truth 用户（点击行为）
behavior_df['dt'] = build_datetime(behavior_df['year'], behavior_df['time_stamp'], behavior_df['timestamp'])
gt_max = behavior_df["dt"].max()
gt_min = gt_max - pd.Timedelta(days=7)
click_df = behavior_df[
    (behavior_df["dt"] >= gt_min) &
    (behavior_df["dt"] <= gt_max) &
    (behavior_df["action_type"].str.lower() == "click")
]
click_df["item_id"] = click_df["item_id"].astype(str)
valid_item_ids = set(item_df["item_id"].astype(str).unique())
click_df = click_df[click_df["item_id"].isin(valid_item_ids)]
gt_users = set(click_df["user_id"].astype(str).unique())

# Recall 用户
recall_users = set(recall_df["user_id"].astype(str).unique())

# 打印交集情况
print("✅ Recall user count:", len(recall_users))
print("✅ Ground Truth user count:", len(gt_users))
print("🔍 Overlap user count:", len(recall_users & gt_users))
# Out:
# /var/folders/gt/0bpw6l095l7fmbtr7428l3n40000gn/T/ipykernel_72737/1580125509.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   click_df["item_id"] = click_df["item_id"].astype(str)
# ✅ Recall user count: 424170
# ✅ Ground Truth user count: 26350
# 🔍 Overlap user count: 26350

# %%
import pandas as pd
from collections import defaultdict
from src.data.load_behavior_log import build_datetime

# ----------- Config -----------
RECALL_CSV = "output/youtube_dnn/youtube_dnn_faiss_recall.csv"
BEHAVIOR_CSV = "data/raw/user_behavior_log_info.csv"
ITEM_CSV = "data/raw/item_metadata.csv"
TOP_K = 10
GROUND_TRUTH_WINDOW_DAYS = 7
NUM_USERS_TO_CHECK = 10

# ----------- 1. Load recall results -----------
recall_df = pd.read_csv(RECALL_CSV)
recall_df["user_id"] = recall_df["user_id"].astype(str)
recall_df["item_id"] = recall_df["item_id"].astype(str)

# ----------- 2. Load item metadata -----------
item_df = pd.read_csv(ITEM_CSV)
valid_item_ids = set(item_df["item_id"].astype(str).unique())

# ----------- 3. Load ground truth -----------
df = pd.read_csv(BEHAVIOR_CSV)
df["dt"] = build_datetime(df["year"], df["time_stamp"], df["timestamp"])
df["item_id"] = df["item_id"].astype(str)
df["user_id"] = df["user_id"].astype(str)

max_dt = df["dt"].max()
min_dt = max_dt - pd.Timedelta(days=GROUND_TRUTH_WINDOW_DAYS)
click_df = df[
    (df["dt"] >= min_dt) &
    (df["dt"] <= max_dt) &
    (df["action_type"].str.lower() == "click") &
    (df["item_id"].isin(valid_item_ids))
].copy()

# Build ground truth dict
gt_dict = defaultdict(set)
for row in click_df.itertuples(index=False):
    gt_dict[row.user_id].add(row.item_id)

# ----------- 4. Analyze first N users with GT -----------
print(f"🧪 分析前 {NUM_USERS_TO_CHECK} 个 Ground Truth 用户:")

checked = 0
for user_id in gt_dict:
    if user_id not in recall_df["user_id"].values:
        continue

    recalled_items = set(
        recall_df[(recall_df["user_id"] == user_id) & (recall_df["rank"] <= TOP_K)]["item_id"]
    )
    clicked_items = gt_dict[user_id]
    hit_items = recalled_items & clicked_items
    missed_items = clicked_items - recalled_items

    print("=" * 40)
    print(f"👤 用户: {user_id}")
    print(f"✅ Ground Truth Clicked Items ({len(clicked_items)}): {clicked_items}")
    print(f"🎯 Recalled Items ({len(recalled_items)}): {recalled_items}")
    print(f"🔥 Hit Items: {hit_items}")
    print(f"❌ Missed Items: {missed_items}")

    checked += 1
    if checked >= NUM_USERS_TO_CHECK:
        break
# Out:
# 🧪 分析前 10 个 Ground Truth 用户:
# ========================================
# 👤 用户: 328862
# ✅ Ground Truth Clicked Items (1): {'406349'}
# 🎯 Recalled Items (10): {'413046', '215089', '201361', '81766', '1089499', '67897', '333159', '671759', '492131', '815434'}
# 🔥 Hit Items: set()
# ❌ Missed Items: {'406349'}
# ========================================
# 👤 用户: 234512
# ✅ Ground Truth Clicked Items (4): {'524779', '758374', '233274', '137298'}
# 🎯 Recalled Items (10): {'413046', '215089', '201361', '81766', '1089499', '67897', '333159', '671759', '492131', '815434'}
# 🔥 Hit Items: set()
# ❌ Missed Items: {'524779', '758374', '137298', '233274'}
# ========================================
# 👤 用户: 356311
# ✅ Ground Truth Clicked Items (11): {'685857', '215289', '931066', '335377', '1016560', '758374', '913290', '998103', '830436', '492131', '269842'}
# 🎯 Recalled Items (10): {'413046', '215089', '201361', '487805', '922514', '1089499', '67897', '333159', '671759', '492131'}
# 🔥 Hit Items: {'492131'}
# ❌ Missed Items: {'685857', '215289', '931066', '335377', '1016560', '758374', '913290', '998103', '830436', '269842'}
# ========================================
# 👤 用户: 272389
# ✅ Ground Truth Clicked Items (1): {'1112375'}
# 🎯 Recalled Items (10): {'215089', '81766', '1089499', '524981', '197239', '67897', '671759', '963870', '943106', '815434'}
# 🔥 Hit Items: set()
# ❌ Missed Items: {'1112375'}
# ========================================
# 👤 用户: 139859
# ✅ Ground Truth Clicked Items (3): {'946684', '333159', '671759'}
# 🎯 Recalled Items (10): {'413046', '215089', '201361', '487805', '922514', '1089499', '67897', '333159', '671759', '492131'}
# 🔥 Hit Items: {'333159', '671759'}
# ❌ Missed Items: {'946684'}
# ========================================
# 👤 用户: 102269
# ✅ Ground Truth Clicked Items (2): {'82939', '222610'}
# 🎯 Recalled Items (10): {'413046', '215089', '201361', '81766', '1089499', '67897', '333159', '671759', '492131', '815434'}
# 🔥 Hit Items: set()
# ❌ Missed Items: {'82939', '222610'}
# ========================================
# 👤 用户: 186568
# ✅ Ground Truth Clicked Items (1): {'183877'}
# 🎯 Recalled Items (10): {'623866', '81766', '1089499', '524981', '197239', '239288', '67897', '963870', '943106', '815434'}
# 🔥 Hit Items: set()
# ❌ Missed Items: {'183877'}
# ========================================
# 👤 用户: 149002
# ✅ Ground Truth Clicked Items (5): {'536300', '989660', '282', '293327', '768559'}
# 🎯 Recalled Items (10): {'81766', '1089499', '524981', '67897', '333159', '671759', '963870', '492131', '943106', '815434'}
# 🔥 Hit Items: set()
# ❌ Missed Items: {'536300', '989660', '282', '293327', '768559'}
# ========================================
# 👤 用户: 92396
# ✅ Ground Truth Clicked Items (5): {'413046', '722907', '1043094', '953159', '997507'}
# 🎯 Recalled Items (10): {'413046', '215089', '81766', '1089499', '67897', '333159', '671759', '492131', '943106', '815434'}
# 🔥 Hit Items: {'413046'}
# ❌ Missed Items: {'953159', '722907', '997507', '1043094'}
# ========================================
# 👤 用户: 37908
# ✅ Ground Truth Clicked Items (3): {'856349', '918243', '704096'}
# 🎯 Recalled Items (10): {'413046', '215089', '81766', '1089499', '524981', '67897', '671759', '963870', '943106', '815434'}
# 🔥 Hit Items: set()
# ❌ Missed Items: {'856349', '918243', '704096'}

# %%
import pandas as pd
import random

# 配置文件路径
RECALL_CSV = "output/youtube_dnn/youtube_dnn_faiss_recall.csv"
BEHAVIOR_CSV = "data/raw/user_behavior_log_info.csv"
ITEM_CSV = "data/raw/item_metadata.csv"

from src.data.load_behavior_log import build_datetime

# -------- 1. 加载数据 --------
recall_df = pd.read_csv(RECALL_CSV)
print(f"召回结果: {recall_df.shape}")

# ground truth 构建
behavior_df = pd.read_csv(BEHAVIOR_CSV)
item_df = pd.read_csv(ITEM_CSV)
valid_item_ids = set(item_df["item_id"].astype(str).unique())

behavior_df["dt"] = build_datetime(
    behavior_df["year"], behavior_df["time_stamp"], behavior_df["timestamp"]
)
max_dt = behavior_df["dt"].max()
min_dt = max_dt - pd.Timedelta(days=30)

click_df = behavior_df[
    (behavior_df["dt"] >= min_dt) &
    (behavior_df["dt"] <= max_dt) &
    (behavior_df["action_type"].str.lower() == "click")
].copy()
click_df["item_id"] = click_df["item_id"].astype(str)
click_df = click_df[click_df["item_id"].isin(valid_item_ids)]

gt_dict = click_df.groupby("user_id")["item_id"].apply(set).to_dict()
print(f"Ground Truth 用户数: {len(gt_dict)}")

# -------- 2. 抽样几个用户 --------
overlap_users = set(recall_df["user_id"].astype(str).unique()) & set(gt_dict.keys())
print(f"交集用户数: {len(overlap_users)}")

sample_users = random.sample(list(overlap_users), 5)

# -------- 3. 打印对比 --------
for u in sample_users:
    gt_items = list(gt_dict[u])[:10]
    rec_items = recall_df[recall_df["user_id"] == u].sort_values("rank")["item_id"].tolist()[:10]
    print(f"\n👤 User {u}")
    print(f"  Ground Truth items: {gt_items}")
    print(f"  Recall items: {rec_items}")
    print(f"  Hit: {set(gt_items) & set(rec_items)}")
# Out:
# 召回结果: (399830, 5)
# Ground Truth 用户数: 36029
# 交集用户数: 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/gt/0bpw6l095l7fmbtr7428l3n40000gn/T/ipykernel_72737/4005056296.py in <module>
#      39 print(f"交集用户数: {len(overlap_users)}")
#      40
# ---> 41 sample_users = random.sample(list(overlap_users), 5)
#      42
#      43 # -------- 3. 打印对比 --------
#
# ~/opt/anaconda3/lib/python3.9/random.py in sample(self, population, k, counts)
#     447         randbelow = self._randbelow
#     448         if not 0 <= k <= n:
# --> 449             raise ValueError("Sample larger than population or is negative")
#     450         result = [None] * k
#     451         setsize = 21        # size of a small set minus size of an empty list
#
# ValueError: Sample larger than population or is negative
